# %% [markdown]
# # 🔁 Módulo 4 — Iteradores en Python
#
# En este notebook aprenderás cómo funciona el **protocolo de iteradores** en Python:
#
# - El método `__iter__()`
# - El método `__next__()`
# - Cómo crear tus propios iteradores
# - Cómo funciona internamente un `for`
# - Uso de `iter()` y `next()`
#
# Este contenido es fundamental para entender **generadores**, **pipelines de datos**, y muchas librerías avanzadas.

# %% [markdown]
# ---
# ## 1️⃣ ¿Qué es un iterador?
#
# Un **iterador** es un objeto que implementa al menos:
#
# ```python
# __iter__()  # devuelve el propio iterador
# __next__()  # devuelve el siguiente valor
# ```
#
# El bucle `for` hace internamente:
#
# ```python
# it = iter(obj)
# while True:
#     valor = next(it)
# ```

# %% [markdown]
# ## 2️⃣ Ejemplo básico con listas
#
# Las listas **son iterables**, pero **no iteradores**.
#
# ```python
# iter([1,2,3])  # OK
# next([1,2,3])  # ERROR
# ```

# %%
numeros = [10, 20, 30]
it = iter(numeros)

print(numeros)
print(it)

next(it), next(it), next(it)
# Out:
# [10, 20, 30]
# <method-wrapper '__str__' of list_iterator object at 0x7a42d42617e0>
# (10, 20, 30)

# %% [markdown]
# Una vez consumido, produce `StopIteration`:

# %%
try:
    next(it)
except StopIteration:
    print("Iterador finalizado")
# Out:
# Iterador finalizado

# %% [markdown]
# ---
# ## 3️⃣ Crear un iterador personalizado
#
# Vamos a crear un iterador que devuelva números del 1 al N.

# %%
class Contador:
    def __init__(self, limite):
        self.limite = limite
        self.actual = 0

    def __iter__(self):
        return self

    def __next__(self):
        if self.actual >= self.limite:
            raise StopIteration
        self.actual += 1
        return self.actual
    
    def __str__(self):
        return str(self.actual)

c = Contador(5)

print(list(c)) # ejecuta Next hasta que acabe el iterador, y devuelve la lista correspondiente

print(c)
# Out:
# [1, 2, 3, 4, 5]
# 5

# %% [markdown]
# Observa que si intentas consumirlo de nuevo, está agotado:

# %%
list(c)
# Out:
# []

# %% [markdown]
# ---
# ## 4️⃣ Iteradores infinitos (⚠️ con cuidado)
#
# Podemos crear iteradores que nunca terminan. Son útiles en streams, ETL por lotes o datos en tiempo real.
#
# Ejemplo:

# %%
class NumerosInfinitos:
    def __init__(self):
        self.n = 0

    def __iter__(self):
        return self

    def __next__(self):
        self.n += 1
        return self.n

it = NumerosInfinitos()
[next(it) for _ in range(5)]
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# ---
# ## 5️⃣ `iter()` con un segundo argumento: sentinela
#
# Forma especial de iterar hasta que se cumple una condición.
#
# ### Ejemplo: leer líneas hasta que sean vacías.

# %%
def leer_linea():
    linea = input().strip()
    return linea

# iter(leer_linea, "FIN")
print("Este ejemplo requiere entrada interactiva, se deja como demostración.")
# Out:
# Este ejemplo requiere entrada interactiva, se deja como demostración.

# %% [markdown]
# ---
# ## 6️⃣ Ejercicio práctico
#
# ### 🧩 Ejercicio
# Crea un iterador `CuentaAtras(inicio)` que produzca:
#
# ```
# 5
# 4
# 3
# 2
# 1
# 0
# ```
#
# y luego lance `StopIteration`.
#
# Prueba:
# ```python
# list(CuentaAtras(5))
# ```

# %%
class CuentaAtras:
    def __init__(self, valorIni):
        self.actual = valorIni

    def __iter__(self):
        return self

    def __next__(self):
        if self.actual == 0:
            raise StopIteration
        else:
            self.actual -= 1
        return self.actual
    
    def __str__(self):
        return str(self.actual)

ca = CuentaAtras(5)

print("Iter inicial:", ca) 

#for x in ca: print(x)

#[x*x for x in ca]

#it = iter(ca)
#print(next(it))
#print(next(it))
#print(next(it))

print(list(ca))

print("Iter final:", ca)
# Out:
# Iter inicial: 5
# []
# Iter final: 0

# %% [markdown]
# ---
# ## ✅ Solución (oculta)
#
# <details>
# <summary>Mostrar solución</summary>
#
# ```python
# class CuentaAtras:
#     def __init__(self, inicio):
#         self.n = inicio
#
#     def __iter__(self):
#         return self
#
#     def __next__(self):
#         if self.n < 0:
#             raise StopIteration
#         valor = self.n
#         self.n -= 1
#         return valor
# ```
#
# ```python
# list(CuentaAtras(5))
# ```
# </details>
