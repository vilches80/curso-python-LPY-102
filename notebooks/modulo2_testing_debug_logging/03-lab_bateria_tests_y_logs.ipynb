# %% [markdown]
# # 🧪 Laboratorio — Batería de Tests + Logging
#
# En este laboratorio combinaremos **pytest** y **logging** para crear un pequeño módulo profesional.
#
# ## 🎯 Objetivos
# - Crear un módulo con funciones reales.
# - Escribir una batería completa de tests.
# - Añadir logging configurable.
# - Ejecutar los tests desde el notebook.
#
# Este lab simula un flujo típico de desarrollo profesional.

# %% [markdown]
# ---
# ## 1️⃣ Crear el módulo principal: `calculadora.py`
#
# El módulo contendrá 3 funciones:
#
# - `sumar(a, b)`
# - `restar(a, b)`
# - `dividir(a, b)`  *(debe lanzar `ValueError` si `b == 0`)*
#
# 📌 Además, debe incluir logging interno.

# %%
# %%writefile calculadora.py
import logging

logger = logging.getLogger(__name__)
logger.setLevel(logging.INFO)

def sumar(a, b):
    logger.info(f"Sumando {a} + {b}")
    return a + b

def restar(a, b):
    logger.info(f"Restando {a} - {b}")
    return a - b

def dividir(a, b):
    logger.info(f"Dividiendo {a} / {b}")
    if b == 0:
        logger.error("Intento de división por cero")
        raise ValueError("No se puede dividir por cero")
    return a / b

print("calculadora.py creado correctamente.")

# %% [markdown]
# ---
# ## 2️⃣ Crear archivo de configuración de logging (opcional)
#
# Usaremos `logging.basicConfig` desde un archivo externo.

# %%
# %%writefile logging_config.py
import logging

logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s [%(levelname)s] %(name)s: %(message)s"
)
print("logging_config.py cargado")

# %% [markdown]
# ---
# ## 3️⃣ Escribir batería de tests con `pytest`
#
# Los tests deben comprobar:
# - Casos típicos
# - Casos negativos
# - Errores esperados
# - Comportamiento de edge cases
#
# 📄 Archivo: `test_calculadora.py`

# %%
# %%writefile test_calculadora.py
import pytest
import logging_config  # activa logging
from calculadora import sumar, restar, dividir

def test_sumar():
    assert sumar(2, 3) == 5
    assert sumar(-1, 1) == 0

def test_restar():
    assert restar(10, 3) == 7
    assert restar(0, 5) == -5

def test_dividir():
    assert dividir(10, 2) == 5
    assert dividir(9, 3) == 3

def test_dividir_cero():
    with pytest.raises(ValueError):
        dividir(8, 0)

print("test_calculadora.py creado")

# %% [markdown]
# ---
# ## 4️⃣ Ejecutar toda la batería de tests
#
# Ejecutamos los tests en modo silencioso con:
#
# ```bash
# pytest -q
# ```

# %%
# !pytest -q

# %% [markdown]
# ---
# ## 5️⃣ Ejercicio final
#
# ### 🧩 Ejercicio
# Añade a `calculadora.py` la función:
#
# ```python
# def multiplicar(a, b):
#     # implementar
# ```
#
# Y crea un nuevo test:
# - Prueba números positivos
# - Prueba números negativos
# - Prueba multiplicar por cero
#
# 📌 Usa logging dentro de la función.
#
# Escribe tu solución abajo.

# %%
# Escribe aquí tu solución

# %% [markdown]
# ---
# ## ✅ Solución (oculta)
#
# <details>
# <summary>Mostrar solución</summary>
#
# ```python
# %%writefile calculadora.py
# import logging
# logger = logging.getLogger(__name__)
# logger.setLevel(logging.INFO)
#
# def sumar(a, b): return a + b
# def restar(a, b): return a - b
#
# def dividir(a, b):
#     if b == 0:
#         raise ValueError("No se puede dividir por cero")
#     return a/b
#
# def multiplicar(a, b):
#     logger.info(f"Multiplicando {a} * {b}")
#     return a * b
# ```
#
# ```python
# %%writefile test_calculadora_extra.py
# from calculadora import multiplicar
#
# def test_multiplicar():
#     assert multiplicar(2, 3) == 6
#     assert multiplicar(-2, 4) == -8
#     assert multiplicar(10, 0) == 0
# ```
#
# </details>
