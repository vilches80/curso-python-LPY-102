# %% [markdown]
# # 🔗 Módulo 7 — Pandas: Mezclas, Joins y Concatenaciones
#
# En este notebook aprenderás todas las técnicas de combinación de datos:
#
# - `concat` (vertical y horizontal)
# - `merge` (inner, left, right, outer)
# - Joins por columna y por índice
# - Uniones avanzadas (one-to-many)
# - `merge_asof` para series temporales
#
# ---

# %% [markdown]
# ## 1️⃣ Dataset de ejemplo

# %%
import pandas as pd
import numpy as np

ventas = pd.DataFrame({
    'id': [1,2,3,4],
    'producto': ['A','B','C','D'],
    'unidades': [10,20,15,8]
})

precios = pd.DataFrame({
    'producto': ['A','B','C','E'],
    'precio': [100, 80, 50, 25]
})

ventas, precios
# Out:
# (   id producto  unidades
#  0   1        A        10
#  1   2        B        20
#  2   3        C        15
#  3   4        D         8,
#    producto  precio
#  0        A     100
#  1        B      80
#  2        C      50
#  3        E      25)

# %% [markdown]
# ---
# ## 2️⃣ Concatenación (`concat`)
#
# ### Vertical (una tabla debajo de otra)

# %%
pd.concat([ventas, ventas])
# Out:
#    id producto  unidades
# 0   1        A        10
# 1   2        B        20
# 2   3        C        15
# 3   4        D         8
# 0   1        A        10
# 1   2        B        20
# 2   3        C        15
# 3   4        D         8

# %% [markdown]
# ### Horizontal (lado a lado)

# %%
pd.concat([ventas, precios], axis=1)
# Out:
#    id producto  unidades producto  precio
# 0   1        A        10        A     100
# 1   2        B        20        B      80
# 2   3        C        15        C      50
# 3   4        D         8        E      25

# %% [markdown]
# ---
# ## 3️⃣ Merge básico (tipo SQL JOIN)
#
# ### Inner Join (solo coincidencias)

# %%
# mezcla solo las coincidencias, por clave 'producto'
ventas.merge(precios, on='producto', how='inner')
# Out:
#    id producto  unidades  precio
# 0   1        A        10     100
# 1   2        B        20      80
# 2   3        C        15      50

# %% [markdown]
# ### Left Join (mantiene las ventas, añade precio donde pueda)

# %%
# mezcla dando prioridad a la tabla izquierda ('ventas'), por clave 'producto'
ventas.merge(precios, on='producto', how='left')
# Out:
#    id producto  unidades  precio
# 0   1        A        10   100.0
# 1   2        B        20    80.0
# 2   3        C        15    50.0
# 3   4        D         8     NaN

# %% [markdown]
# ### Right Join (mantiene los precios)

# %%
# mezcla dando prioridad a la tabla derecha ('precios'), por clave 'producto'
ventas.merge(precios, on='producto', how='right')
# Out:
#     id producto  unidades  precio
# 0  1.0        A      10.0     100
# 1  2.0        B      20.0      80
# 2  3.0        C      15.0      50
# 3  NaN        E       NaN      25

# %% [markdown]
# ### Outer Join (todo con todo)

# %%
# mezcla todo con todo, por clave 'producto'
ventas.merge(precios, on='producto', how='outer')
# Out:
#     id producto  unidades  precio
# 0  1.0        A      10.0   100.0
# 1  2.0        B      20.0    80.0
# 2  3.0        C      15.0    50.0
# 3  4.0        D       8.0     NaN
# 4  NaN        E       NaN    25.0

# %% [markdown]
# ---
# ## 4️⃣ Merge con diferentes nombres de columnas
#
# Ejemplo: columna `producto` en una tabla y `item` en otra.

# %%
precios_alt = precios.rename(columns={'producto':'item'})
ventas.merge(precios_alt, left_on='producto', right_on='item', how='left')
# Out:
#    id producto  unidades item  precio
# 0   1        A        10    A   100.0
# 1   2        B        20    B    80.0
# 2   3        C        15    C    50.0
# 3   4        D         8  NaN     NaN

# %% [markdown]
# ---
# ## 5️⃣ Merge por índice

# %%
ventas_idx = ventas.set_index('producto')
precios_idx = precios.set_index('producto')

ventas_idx.join(precios_idx, how='left')
# Out:
#           id  unidades  precio
# producto
# A          1        10   100.0
# B          2        20    80.0
# C          3        15    50.0
# D          4         8     NaN

# %% [markdown]
# ---
# ## 6️⃣ Many-to-Many
# Ejemplo con categorías múltiples por producto:

# %%
categorias = pd.DataFrame({
    'producto': ['A','A','B','C','C','C'],
    'categoria': ['x','y','x','x','y','z']
})

ventas.merge(categorias, on='producto')
# Out:
#    id producto  unidades categoria
# 0   1        A        10         x
# 1   1        A        10         y
# 2   2        B        20         x
# 3   3        C        15         x
# 4   3        C        15         y
# 5   3        C        15         z

# %% [markdown]
# ---
# ## 7️⃣ Joins temporales — `merge_asof`
#
# Perfecto para series temporales donde quieres unir por *proximidad*.

# %%
ts1 = pd.DataFrame({
    'fecha': pd.date_range('2024-01-01', periods=5),
    'valor': [10,20,30,40,50]
})

ts2 = pd.DataFrame({
    'fecha': pd.date_range('2024-01-01', periods=3, freq='2D'),
    'precio': [5, 6, 7]
})

print(ts1)
print(ts2)
print(pd.merge_asof(ts1, ts2, on='fecha'))
# Out:
#        fecha  valor
# 0 2024-01-01     10
# 1 2024-01-02     20
# 2 2024-01-03     30
# 3 2024-01-04     40
# 4 2024-01-05     50
#        fecha  precio
# 0 2024-01-01       5
# 1 2024-01-03       6
# 2 2024-01-05       7
#        fecha  valor  precio
# 0 2024-01-01     10       5
# 1 2024-01-02     20       5
# 2 2024-01-03     30       6
# 3 2024-01-04     40       6
# 4 2024-01-05     50       7

# %% [markdown]
# ---
# ## 8️⃣ Ejercicio práctico
#
# Usando `ventas` y `precios`:
#
# ### 🧩 Objetivos
# 1. Realiza un **left join** para añadir precios a ventas
# 2. Calcula una columna `total = unidades * precio`
# 3. Haz un **inner join** y observa qué productos desaparecen
# 4. Crea una tabla `info` con columnas renombradas (`item`, `valor`) y haz el merge correcto
# 5. Haz un merge many-to-many usando la tabla `categorias`
#
# Escribe tu solución abajo:

# %%
import pandas as pd
import numpy as np

ventasEj = pd.DataFrame({
    'id': [1,2,3,4],
    'producto': ['A','B','C','D'],
    'unidades': [10,20,15,8]
})

preciosEj = pd.DataFrame({
    'producto': ['A','B','C','E'],
    'precio': [100, 80, 50, 25]
})

print("//-- Datos ini: --//")
print(ventasEj)
print(preciosEj)
print()
# Out:
# //-- Datos ini: --//
#    id producto  unidades
# 0   1        A        10
# 1   2        B        20
# 2   3        C        15
# 3   4        D         8
#   producto  precio
# 0        A     100
# 1        B      80
# 2        C      50
# 3        E      25

# %%
print("1. Merge Left Join:")
ventasL = ventasEj.merge(precios2, on='producto', how='left')
print(ventasL)
print()
# Out:
# 1. Merge Left Join:
#    id producto  unidades  precio
# 0   1        A        10   100.0
# 1   2        B        20    80.0
# 2   3        C        15    50.0
# 3   4        D         8     NaN

# %%
print("2. Nueva columna 'total':")
ventasL['total'] = ventasL['precio'] * ventasL['unidades']
print(ventasL)
print()
# Out:
# 2. Nueva columna 'total':
#    id producto  unidades  precio   total
# 0   1        A        10   100.0  1000.0
# 1   2        B        20    80.0  1600.0
# 2   3        C        15    50.0   750.0
# 3   4        D         8     NaN     NaN

# %%
print("3. Merge Inner Join:")
ventasI = ventasEj.merge(preciosEj, on='producto', how='inner')
print(ventasI)
print()
# Out:
# 3. Merge Inner Join:
#    id producto  unidades  precio
# 0   1        A        10     100
# 1   2        B        20      80
# 2   3        C        15      50

# %%
print("4. Nueva tabla info:")
preciosInfo = preciosEj.rename(columns={'producto':'item', 'precio':'valor'})
print(preciosInfo)
print("4.-- Merge ventas-info:")
ventasInfo = ventasEj.merge(preciosInfo, left_on='producto', right_on='item')#, how='left')
print(ventasInfo)
print()
# Out:
# 4. Nueva tabla info:
#   item  valor
# 0    A    100
# 1    B     80
# 2    C     50
# 3    E     25
# 4.-- Merge ventas-info:
#    id producto  unidades item  valor
# 0   1        A        10    A  100.0
# 1   2        B        20    B   80.0
# 2   3        C        15    C   50.0
# 3   4        D         8  NaN    NaN

# %%
print("5. Merge Many-to-Many:")
categoriasEj = pd.DataFrame({
    'producto': ['A','A','B','C','C','C'],
    'categoria': ['x','y','x','x','y','z']
})
print(categoriasEj)
ventasCat = ventasEj.merge(categoriasEj, on='producto')
print(ventasCat)
print()
# Out:
# 5. Merge Many-to-Many:
#   producto categoria
# 0        A         x
# 1        A         y
# 2        B         x
# 3        C         x
# 4        C         y
# 5        C         z
#    id producto  unidades categoria
# 0   1        A        10         x
# 1   1        A        10         y
# 2   2        B        20         x
# 3   3        C        15         x
# 4   3        C        15         y
# 5   3        C        15         z

# %%
print("//-- Datos fin: --//")
print(ventasEj)
print(preciosEj)
print()
# Out:
# //-- Datos fin: --//
#    id producto  unidades
# 0   1        A        10
# 1   2        B        20
# 2   3        C        15
# 3   4        D         8
#   producto  precio
# 0        A     100
# 1        B      80
# 2        C      50
# 3        E      25

# %% [markdown]
# ---
# ## ✅ Solución (oculta)
# <details>
# <summary>Mostrar soluciones</summary>
#
# ```python
# left = ventas.merge(precios, on='producto', how='left')
# ```
# ```python
# left['total'] = left['unidades'] * left['precio']
# ```
# ```python
# inner = ventas.merge(precios, on='producto', how='inner')
# ```
# ```python
# info = precios.rename(columns={'producto':'item','precio':'valor'})
# ventas.merge(info, left_on='producto', right_on='item')
# ```
# ```python
# ventas.merge(categorias, on='producto')
# ```
# </details>
