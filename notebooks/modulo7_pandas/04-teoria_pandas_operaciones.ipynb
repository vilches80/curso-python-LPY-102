# %% [markdown]
# # 🛠️ Módulo 7 — Pandas: Operaciones y Transformaciones
#
# En este notebook aprenderás a transformar datos de forma profesional con Pandas:
#
# - Operaciones columna a columna
# - Operaciones vectorizadas
# - `apply`, `map`, `replace`
# - Operaciones fila a fila (`axis=1`)
# - Tratamiento de valores nulos (`fillna`, `dropna`)
# - Funciones agregadas (`agg`, `transform`)
#
# ---

# %% [markdown]
# ## 1️⃣ Dataset de ejemplo

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({
    'producto': ['A','B','C','D','E'],
    'precio': [10, 20, 5, 8, np.nan],
    'unidades': [100, 50, 30, 80, 60]
})
df
# Out:
#   producto  precio  unidades
# 0        A    10.0       100
# 1        B    20.0        50
# 2        C     5.0        30
# 3        D     8.0        80
# 4        E     NaN        60

# %% [markdown]
# ---
# ## 2️⃣ Operaciones columna a columna (vectorizadas)
#
# Crear una columna `total`:

# %%
df['total'] = df['precio'] * df['unidades']
df
# Out:
#   producto  precio  unidades   total
# 0        A    10.0       100  1000.0
# 1        B    20.0        50  1000.0
# 2        C     5.0        30   150.0
# 3        D     8.0        80   640.0
# 4        E     NaN        60     NaN

# %% [markdown]
# ---
# ## 3️⃣ Operaciones elemento a elemento
#
# Incrementar el precio un 10%:

# %%
# puedes sobreescribir columna, o crear una columna nueva
df['precio_incrementado'] = df['precio'] * 1.10
df[['producto','precio','precio_incrementado']]
# Out:
#   producto  precio  precio_incrementado
# 0        A    10.0                 11.0
# 1        B    20.0                 22.0
# 2        C     5.0                  5.5
# 3        D     8.0                  8.8
# 4        E     NaN                  NaN

# %% [markdown]
# ---
# ## 4️⃣ `apply` → aplicar funciones complejas
#
# Aplicar una función a una columna:

# %%
df['precio_clasificacion'] = df['precio'].apply(lambda x: 'alto' if x >= 10 else 'bajo')
df[['producto','precio','precio_clasificacion']]
# Out:
#   producto  precio precio_clasificacion
# 0        A    10.0                 alto
# 1        B    20.0                 alto
# 2        C     5.0                 bajo
# 3        D     8.0                 bajo
# 4        E     NaN                 bajo

# %% [markdown]
# ### `apply` fila a fila (`axis=1`)
# Calcular margen unitario:

# %%
# recorremos el DF fila por fila (o por columna, con axis=0)
df['margen'] = df.apply(lambda fila: fila['precio'] - 2, axis=1)
df[['producto','precio','margen']]
# Out:
#   producto  precio  margen
# 0        A    10.0     8.0
# 1        B    20.0    18.0
# 2        C     5.0     3.0
# 3        D     8.0     6.0
# 4        E     NaN     NaN

# %% [markdown]
# ---
# ## 5️⃣ `map` y `replace`
#
# Convertir códigos a etiquetas:

# %%
# apply le pasa una lambda. Map lo que hace es mapear valores
categorias = { 'A':'premium', 'B':'normal', 'C':'normal', 'D':'lowcost', 'E':'lowcost' }
df['tipo'] = df['producto'].map(categorias)
df[['producto','tipo']]
# Out:
#   producto     tipo
# 0        A  premium
# 1        B   normal
# 2        C   normal
# 3        D  lowcost
# 4        E  lowcost

# %% [markdown]
# `replace` también permite sustituir valores:

# %%
# tecnica de sanitizacion para sustituir valores.
# Se pueden hacer replace condicionales, con funciones lambda, etc
df['precio_reemplazo'] = df['precio'].replace({np.nan: 0})
df[['precio','precio_reemplazo']]
# Out:
#    precio  precio_reemplazo
# 0    10.0              10.0
# 1    20.0              20.0
# 2     5.0               5.0
# 3     8.0               8.0
# 4     NaN               0.0

# %% [markdown]
# ---
# ## 6️⃣ Tratamiento de nulos
#
# Ver qué valores faltan:

# %%
df.isna()
# Out:
#    producto  precio  unidades  total  precio_incrementado  \
# 0     False   False     False  False                False
# 1     False   False     False  False                False
# 2     False   False     False  False                False
# 3     False   False     False  False                False
# 4     False    True     False   True                 True
#
#    precio_clasificacion  margen   tipo  precio_reemplazo
# 0                 False   False  False             False
# 1                 False   False  False             False
# 2                 False   False  False             False
# 3                 False   False  False             False
# 4                 False    True  False             False

# %%
df.fillna(df['precio'].mean())
# Out:
#   producto  precio  unidades    total  precio_incrementado  \
# 0        A   10.00       100  1000.00                11.00
# 1        B   20.00        50  1000.00                22.00
# 2        C    5.00        30   150.00                 5.50
# 3        D    8.00        80   640.00                 8.80
# 4        E   10.75        60    10.75                10.75
#
#   precio_clasificacion  margen     tipo  precio_reemplazo
# 0                 alto    8.00  premium              10.0
# 1                 alto   18.00   normal              20.0
# 2                 bajo    3.00   normal               5.0
# 3                 bajo    6.00  lowcost               8.0
# 4                 bajo   10.75  lowcost               0.0

# %% [markdown]
# Eliminar filas con nulos:

# %%
df.dropna()
# Out:
#   producto  precio  unidades   total  precio_incrementado  \
# 0        A    10.0       100  1000.0                 11.0
# 1        B    20.0        50  1000.0                 22.0
# 2        C     5.0        30   150.0                  5.5
# 3        D     8.0        80   640.0                  8.8
#
#   precio_clasificacion  margen     tipo  precio_reemplazo
# 0                 alto     8.0  premium              10.0
# 1                 alto    18.0   normal              20.0
# 2                 bajo     3.0   normal               5.0
# 3                 bajo     6.0  lowcost               8.0

# %% [markdown]
# ---
# ## 7️⃣ Agregaciones (`agg`)
#
# Obtener estadísticas múltiples a la vez:

# %%
# En el ej usa funciones propias del DF (mean, min, max)
# Tambien prodían usarse funciones lambda
df.agg({'precio':['mean','min','max'], 'unidades':['sum','mean']})
# Out:
#       precio  unidades
# mean   10.75      64.0
# min     5.00       NaN
# max    20.00       NaN
# sum      NaN     320.0

# %% [markdown]
# ---
# ## 8️⃣ Transformaciones (`transform`)
#
# `transform` devuelve una Serie del mismo tamaño que la entrada.

# %%
df['unidades_norm'] = df['unidades'].transform(lambda x: (x - x.mean()) / x.std())
df[['unidades','unidades_norm']]
# Out:
#    unidades  unidades_norm
# 0       100       1.332420
# 1        50      -0.518163
# 2        30      -1.258396
# 3        80       0.592187
# 4        60      -0.148047

# %% [markdown]
# ---
# ## 9️⃣ Ejercicio práctico
#
# ### 🧩 Objetivos
# Usando el DataFrame `df`:
#
# 1. Completa los nulos de `precio` con la media
# 2. Crea una columna `valor_total = precio * unidades`
# 3. Crea una columna `categoria_precio`:
#    - 'alto' si precio ≥ 15
#    - 'medio' si precio entre 8 y 14
#    - 'bajo' si precio < 8
# 4. Normaliza la columna `unidades` con `transform`
# 5. Usa `agg` para obtener media y varianza de `precio` y `unidades`
#
# Escribe tu solución abajo:

# %%
df2 = pd.DataFrame({
    'producto': ['A','B','C','D','E'],
    'precio': [10, 20, 5, 8, np.nan],
    'unidades': [100, 50, 30, 80, 60]
})

print("//-- Datos ini: --//")
print(df2)
print()

print("1. Datos nulos:")
print(df2.isna())
print("1.-- Datos nulos corregidos con la media:")
df2 = df2.fillna(df['precio'].mean())
print(df2)
print()

print("2. Nueva columna 'valor_total':")
df2['valor_total'] = df2['precio'] * df2['unidades']
print(df2)
print()

print("3. Nueva columna 'categoria_precio':")
#fnMay8 = lambda x: 'medio' if x >= 8 else 'bajo'
#fnCat = lambda x: 'alto' if x >= 15 else fnMay8(x)
fnCat = lambda x: 'alto' if x >= 15 else ('medio' if x >= 8 else 'bajo')
df2['categoria_precio'] = df2['precio'].apply(fnCat)
print(df2)
print()

print("4. Normalizar columna 'unidades':")
fnNorm = lambda x: (x - x.mean()) / x.std()
df2['unidades_norm'] = df2['unidades'].transform(fnNorm)
print(df2)
print()

print("5. Media y varianza de 'precio' y 'unidades':")
dfAgg = df2.agg({'precio':['mean','var'], 'unidades':['mean', 'var']})
print(dfAgg)
print()

print("//-- Datos fin: --//")
print(df2)
print()
# Out:
# //-- Datos ini: --//
#   producto  precio  unidades
# 0        A    10.0       100
# 1        B    20.0        50
# 2        C     5.0        30
# 3        D     8.0        80
# 4        E     NaN        60
#
# 1. Datos nulos:
#    producto  precio  unidades
# 0     False   False     False
# 1     False   False     False
# 2     False   False     False
# 3     False   False     False
# 4     False    True     False
# 1.-- Datos nulos corregidos con la media:
#   producto  precio  unidades
# 0        A   10.00       100
# 1        B   20.00        50
# 2        C    5.00        30
# 3        D    8.00        80
# 4        E   10.75        60
#
# 2. Nueva columna 'valor_total':
#   producto  precio  unidades  valor_total
# 0        A   10.00       100       1000.0
# 1        B   20.00        50       1000.0
# 2        C    5.00        30        150.0
# 3        D    8.00        80        640.0
# 4        E   10.75        60        645.0
#
# 3. Nueva columna 'categoria_precio':
#   producto  precio  unidades  valor_total categoria_precio
# 0        A   10.00       100       1000.0            medio
# 1        B   20.00        50       1000.0             alto
# 2        C    5.00        30        150.0             bajo
# 3        D    8.00        80        640.0            medio
# 4        E   10.75        60        645.0            medio
#
# 4. Normalizar columna 'unidades':
#   producto  precio  unidades  valor_total categoria_precio  unidades_norm
# 0        A   10.00       100       1000.0            medio       1.332420
# 1        B   20.00        50       1000.0             alto      -0.518163
# 2        C    5.00        30        150.0             bajo      -1.258396
# 3        D    8.00        80        640.0            medio       0.592187
# 4        E   10.75        60        645.0            medio      -0.148047
#
# 5. Media y varianza de 'precio' y 'unidades':
#        precio  unidades
# mean  10.7500      64.0
# var   31.6875     730.0
#
# //-- Datos fin: --//
#   producto  precio  unidades  valor_total categoria_precio  unidades_norm
# 0        A   10.00       100       1000.0            medio       1.332420
# 1        B   20.00        50       1000.0             alto      -0.518163
# 2        C    5.00        30        150.0             bajo      -1.258396
# 3        D    8.00        80        640.0            medio       0.592187
# 4        E   10.75        60        645.0            medio      -0.148047

# %% [markdown]
# ---
# ## ✅ Solución (oculta)
#
# <details>
# <summary>Mostrar soluciones</summary>
#
# ```python
# df['precio'] = df['precio'].fillna(df['precio'].mean())
# ```
#
# ```python
# df['valor_total'] = df['precio'] * df['unidades']
# ```
#
# ```python
# df['categoria_precio'] = df['precio'].apply(
#     lambda x: 'alto' if x>=15 else ('medio' if x>=8 else 'bajo')
# )
# ```
#
# ```python
# df['unidades_norm'] = df['unidades'].transform(lambda x: (x-x.mean())/x.std())
# ```
#
# ```python
# df.agg({'precio':['mean','var'], 'unidades':['mean','var']})
# ```
# </details>
