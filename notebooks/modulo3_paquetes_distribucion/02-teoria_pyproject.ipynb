# %% [markdown]
# # 📦 Módulo 3 — Empaquetado Moderno con `pyproject.toml`
#
# En este notebook aprenderás a crear un paquete moderno en Python utilizando el estándar **PEP 517/518**, cuyo núcleo es el archivo `pyproject.toml`.
#
# ## 🎯 Objetivos
# - Entender qué es `pyproject.toml` y por qué reemplaza a `setup.py`.
# - Crear un paquete instalable.
# - Definir dependencias.
# - Crear scripts ejecutables (entry points).
# - Instalar un paquete localmente en editable.
#
# Este módulo es esencial para distribuir librerías Python profesionalmente.

# %% [markdown]
# ---
# ## 1️⃣ ¿Qué es `pyproject.toml`?
#
# `pyproject.toml` se introdujo como un estándar para definir:
# - Herramienta de build
# - Dependencias
# - Configuración del proyecto
#
# Hoy es la forma recomendada de empaquetar proyectos Python.
#
# Ejemplo mínimo:
# ```toml
# [build-system]
# requires = ["setuptools"]
# build-backend = "setuptools.build_meta"
# ```

# %% [markdown]
# ## 2️⃣ Crear un proyecto de ejemplo
#
# Vamos a crear una estructura profesional:

# %%
# %%bash
# mkdir -p paquete_demo/src/paquete_demo
# touch paquete_demo/src/paquete_demo/__init__.py
# echo "def hola(): return 'Hola desde paquete_demo'" > paquete_demo/src/paquete_demo/saludos.py
# echo "Proyecto base creado en paquete_demo/"
# Out:
# Proyecto base creado en paquete_demo/

# %% [markdown]
# ---
# ## 3️⃣ Crear el archivo `pyproject.toml`
#
# Incluye:
# - Información del proyecto
# - Configuración de setuptools
# - Script ejecutable (entry point)
#
# 📌 Este archivo se escribirá en `paquete_demo/pyproject.toml`.

# %%
# %%writefile paquete_demo/pyproject.toml
# [build-system]
# requires = ["setuptools>=61.0"]
# build-backend = "setuptools.build_meta"
#
# [project]
# name = "paquete_demo"
# version = "0.1.0"
# description = "Un paquete de ejemplo para el curso LPY-102"
# authors = [ { name = "Daniel", email = "dvilches@indra.es" } ]
# readme = "README.md"
# requires-python = ">=3.8"
# dependencies = []
#
# [project.scripts]
# demo-saludo = "paquete_demo.saludos:hola"
#
# [tool.setuptools]
# package-dir = {"" = "src"}
#
# [tool.setuptools.packages.find]
# where = ["src"]
# Out:
# Writing paquete_demo/pyproject.toml

# %% [markdown]
# 📄 Esto crea un comando ejecutable:
#
# ```bash
# demo-saludo
# ```
#
# …que ejecutará `paquete_demo.saludos:hola`.

# %% [markdown]
# ---
# ## 4️⃣ Instalar el paquete en modo editable
#
# Para instalar el paquete localmente durante el desarrollo, usamos:
#
# ```bash
# pip install -e .
# ```
#
# Desde el notebook:

# %%
# %%bash
# cd paquete_demo
# pip install -e . > /dev/null
# echo "Paquete instalado en modo editable"
# Out:
# Paquete instalado en modo editable

# %% [markdown]
# ---
# ## 5️⃣ Probar el paquete instalado
#
# ### Import desde Python:

# %%
from paquete_demo.saludos import hola
hola()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from paquete_demo.saludos import hola
#       2 hola()
#
# ModuleNotFoundError: No module named 'paquete_demo.saludos'

# %% [markdown]
# ### Probar el entry point desde consola (si tu entorno lo permite):
#
# ```bash
# demo-saludo
# ```
#
# Esto imprimirá:
# ```
# Hola desde paquete_demo
# ```

# %% [markdown]
# ---
# ## 6️⃣ Ejercicio práctico
#
# ### 🧩 Ejercicio
# Crea un nuevo paquete llamado `gestion_clientes` con:
#
# - Módulo `clientes.py`
# - Función `contar_clientes(lista)`
# - Define un entry point `cuenta-clientes` que llame a esa función.
#
# Prueba a instalarlo en modo editable y ejecutar el script.

# %%
# Escribe tu solución aquí

# %% [markdown]
# ---
# ## ✅ Solución (oculta)
#
# <details>
# <summary>Mostrar solución</summary>
#
# ```bash
# mkdir -p gestion_clientes/src/gestion_clientes
# echo "def contar_clientes(l): return len(l)" > gestion_clientes/src/gestion_clientes/clientes.py
# touch gestion_clientes/src/gestion_clientes/__init__.py
# ```
#
# ```toml
# [project]
# name = "gestion_clientes"
# version = "0.1.0"
#
# [project.scripts]
# cuenta-clientes = "gestion_clientes.clientes:contar_clientes"
# ```
#
# ```bash
# cd gestion_clientes
# pip install -e .
# cuenta-clientes
# ```
# </details>
